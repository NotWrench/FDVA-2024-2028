# %%
import pandas as pd

df = pd.read_csv('expt.csv')
df.head()
# Out:
#   Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001    Male     Yes          0      Graduate            No
# 1   LP002  Female      No          1      Graduate            No
# 2   LP003    Male     Yes          2  Not Graduate           Yes
# 3   LP004    Male     Yes         3+      Graduate            No
# 4   LP005  Female      No          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5000               1500         120               360
# 1             4200                  0         100               360
# 2             6500               1200         150               360
# 3             7800               1800         200               360
# 4             3500                500          90               180
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           Y
# 2               0     Semiurban           N
# 3               1         Urban           Y
# 4               1         Rural           Y

# %%
print(df.head())
print(df.tail())
print(df.info())
print(df.describe())
print(df.columns)
# Out:
#   Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001    Male     Yes          0      Graduate            No
# 1   LP002  Female      No          1      Graduate            No
# 2   LP003    Male     Yes          2  Not Graduate           Yes
# 3   LP004    Male     Yes         3+      Graduate            No
# 4   LP005  Female      No          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5000               1500         120               360
# 1             4200                  0         100               360
# 2             6500               1200         150               360
# 3             7800               1800         200               360
# 4             3500                500          90               180
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           Y
# 2               0     Semiurban           N
# 3               1         Urban           Y
# 4               1         Rural           Y
#   Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1   LP002  Female      No          1      Graduate            No
# 2   LP003    Male     Yes          2  Not Graduate           Yes
# 3   LP004    Male     Yes         3+      Graduate            No
# 4   LP005  Female      No          0      Graduate           Yes
# 5   LP006    Male     Yes          1  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4200                  0         100               360
# 2             6500               1200         150               360
# 3             7800               1800         200               360
# 4             3500                500          90               180
# 5             4800               1000         130               360
#
#    Credit_History Property_Area Loan_Status
# 1               1         Rural           Y
# 2               0     Semiurban           N
# 3               1         Urban           Y
# 4               1         Rural           Y
# 5               0     Semiurban           N
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            6 non-null      object
#  1   Gender             6 non-null      object
#  2   Married            6 non-null      object
#  3   Dependents         6 non-null      object
#  4   Education          6 non-null      object
#  5   Self_Employed      6 non-null      object
#  6   ApplicantIncome    6 non-null      int64
#  7   CoapplicantIncome  6 non-null      int64
#  8   LoanAmount         6 non-null      int64
#  9   Loan_Amount_Term   6 non-null      int64
#  10  Credit_History     6 non-null      int64
#  11  Property_Area      6 non-null      object
#  12  Loan_Status        6 non-null      object
# dtypes: int64(5), object(8)
# memory usage: 756.0+ bytes
# None
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count         6.000000           6.000000    6.000000          6.000000
# mean       5300.000000        1000.000000  131.666667        330.000000
# std        1579.873413         660.302961   39.707262         73.484692
# min        3500.000000           0.000000   90.000000        180.000000
# 25%        4350.000000         625.000000  105.000000        360.000000
# 50%        4900.000000        1100.000000  125.000000        360.000000
# 75%        6125.000000        1425.000000  145.000000        360.000000
# max        7800.000000        1800.000000  200.000000        360.000000
#
#        Credit_History
# count        6.000000
# mean         0.666667
# std          0.516398
# min          0.000000
# 25%          0.250000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
categorical_cols = ['Gender', 'Married', 'Dependents', 'Education',
                    'Self_Employed', 'Property_Area']

for col in categorical_cols:
    print(f"\nUnique values in '{col}':")
    print(df[col].unique())
# Out:
# Unique values in 'Gender':
# ['Male' 'Female']
#
# Unique values in 'Married':
# ['Yes' 'No']
#
# Unique values in 'Dependents':
# ['0' '1' '2' '3+']
#
# Unique values in 'Education':
# ['Graduate' 'Not Graduate']
#
# Unique values in 'Self_Employed':
# ['No' 'Yes']
#
# Unique values in 'Property_Area':
# ['Urban' 'Rural' 'Semiurban']

# %%
df['Dependents'] = df['Dependents'].replace('3+', 3)
df['Dependents'] = pd.to_numeric(df['Dependents'],
                                 errors='coerce').astype('Int64')

print(df['Dependents'].value_counts(dropna=False))
# Out:
# Dependents
# 0    2
# 1    2
# 2    1
# 3    1
# Name: count, dtype: Int64

# %%
cols = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']

for col in cols:
    print(f"\nStatistics for '{col}':")
    print(f"Mean: {df[col].mean():.2f}")
    print(f"Median: {df[col].median():.2f}")
    print(f"Mode: {df[col].mode().values}")
    print(f"Range: {df[col].max() - df[col].min():.2f}")
    print(f"Variance: {df[col].var():.2f}")
    print(f"Standard Deviation: {df[col].std():.2f}")
# Out:
# Statistics for 'ApplicantIncome':
# Mean: 5750.00
# Median: 5300.00
# Mode: [3500 3900 4200 4800 5000 5600 6500 7200 7800 9000]
# Range: 5500.00
# Variance: 3311666.67
# Standard Deviation: 1819.80
#
# Statistics for 'CoapplicantIncome':
# Mean: 1010.00
# Median: 1100.00
# Mode: [0]
# Range: 2000.00
# Variance: 478777.78
# Standard Deviation: 691.94
#
# Statistics for 'LoanAmount':
# Mean: 147.00
# Median: 135.00
# Mode: [ 90 100 110 120 130 140 150 180 200 250]
# Range: 160.00
# Variance: 2490.00
# Standard Deviation: 49.90
